# %% [markdown]
# ---
#
# <span style="font-size:1.5em;">
# <div class="alert alert-success">
#     <center>AA 5750 Homework Week #2</center>
#     <center>25 Points</center>
#     <center>Due: Sunday 11/6 at 11:59PM</center>
# </div>
# </span>
#
# ---

# %% [markdown]
# # Instructions
# <ol>
#   <li>Save this .ipynb file to your computer</li>
#   <li>Rename it to include your name, such as <font color=blue>Homework 2 - Keith H.ipynb</font></li>
#   <li>Start a command shell, and <font color=blue>cd </font> to your desired folder</li>
#   <li>Be sure you are in the tf2 environment with command <font color=blue>conda activate tf2 </font></li>
#   <li>Start up your Jupyter Notebook environment with command <font color=blue>jupyter notebook</font></li>
#   <li>Load in this renamed .ipynb file and run every cell</li>
#   <li>I have left the output from my computer as an example for you. Your results will likely differ a bit</li>
#   <li>If some cells don't run, and if you cannot fix them, <b>post questions on the discussion board</b> <br>You might need to install some additional packages (Hint: if the 'import' command gives an error, you likely need to install that package)</br></li>
#   <li>Note some cells are Markdown. This cell is! <b>Double Click</b> Markdown cells to see the Markdown code or modify it to your liking - explore!</li>
#   <li> Feel free to add any additional cells you like - Experiment!</li>
#   <li><b> <font color=blue>After running the entire Notebook, save it and turn the .ipynb file in on Canvas </font></b> </li>
#   <li>Relax (<b><font color=blue>cold beverages</font></b> allowed), you got 25 points! </li>
# </ol>

# %%
# This records when you started running this Notebook
import time
start = time.time()

# %% [markdown]
# <span style="font-size:1.8em;">
#
# <div class="alert alert-danger" role="alert">
#     <center>
#
#  <div class="alert alert-danger" role="alert">   <span style="font-size:0.8em;">
#      Note in the following cell the instuctions to <b>add your name</b><br></center>
# </div>

# %%
# Edit this cell to add your name

My_Name = "Srijesh Reddy yarram"    # <<--------------------- Note to change this!

print("This Jupyter Notebook run by:",My_Name)
# Out:
# This Jupyter Notebook run by: Srijesh Reddy yarram

# %%
import datetime as dt  
dt.datetime.today().strftime("%m/%d/%Y %H:%M:%S %p")
# Out:
# '11/04/2022 11:01:26 AM'

# %%
#Lets find out about your system. This will help if you need assistance debugging code.
import sys
print(sys.executable)
print()
print(sys.version)
print()
print(sys.version_info)
print()
print(sys.platform)
print()
print("---------------------------------\n")
# Out:
# /Users/srijesh/opt/anaconda3/envs/tf2/bin/python
#
# 3.9.13 (main, Oct 13 2022, 16:12:30)
# [Clang 12.0.0 ]
#
# sys.version_info(major=3, minor=9, micro=13, releaselevel='final', serial=0)
#
# darwin
#
# ---------------------------------

# %%
#Computer platform

print(sys.platform)
# Out:
# darwin

# %%
if 'darwin' in sys.platform:
    print("Looks like you have a Mac!")
else:
    print("What kind of computer do you have?")
# Out:
# Looks like you have a Mac!

# %%
import os
os.name
# Out:
# 'posix'

# %%
import platform
platform.platform()
# Out:
# 'macOS-10.14.6-x86_64-i386-64bit'

# %%
import tensorflow as tf
print (tf.__version__)
# Out:
# 2.9.1

# %%
#Which Python version are you using?
# !python --version
# Out:
# Python 3.9.13

# %%
# !pip --version
# Out:
# pip 22.2.2 from /Users/srijesh/opt/anaconda3/lib/python3.9/site-packages/pip (python 3.9)

# %%
# !conda --version
# Out:
# conda 22.9.0

# %%
#Which environment are you using (will have an astrisks '*' in front of it):
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /Users/srijesh/opt/anaconda3
# tf2                      /Users/srijesh/opt/anaconda3/envs/tf2

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#     <b>Note:</b> I manage <b>several</b> environments to keep up with Python changes and update/correct code for you in this class!
# </div>

# %%
# !conda info
# Out:
#      active environment : base
#     active env location : /Users/srijesh/opt/anaconda3
#             shell level : 1
#        user config file : /Users/srijesh/.condarc
#  populated config files : /Users/srijesh/.condarc
#           conda version : 22.9.0
#     conda-build version : 3.22.0
#          python version : 3.9.13.final.0
#        virtual packages : __osx=10.14.6=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /Users/srijesh/opt/anaconda3  (writable)
#       conda av data dir : /Users/srijesh/opt/anaconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /Users/srijesh/opt/anaconda3/pkgs
# ...

# %% [markdown]
# ---
# # Getting directory info
# > From:
# https://docs.python.org/3/library/os.html#os.environ
#
# #### You need to know which directories your in so you can find your Notebook files

# %%
import os
print(os.environ['HOME'])

# Windows PC users may not have 'HOME'
# Out:
# /Users/srijesh

# %%
print(os.environ['PATH'])
# Out:
# /Users/srijesh/opt/anaconda3/bin:/Users/srijesh/opt/anaconda3/condabin:/Users/srijesh/anaconda3/bin:/Library/Frameworks/Python.framework/Versions/3.7/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/usr/local/mysql/bin

# %% [markdown]
# ---
# ## Tips and Tricks Demo - See if these work (or not) on your computer
#
# #### You may need to install *matplotlib*.  For example, '!conda install matplotlib' or start a command shell and install it

# %%
#Allows plots in Notebooks

# !conda install matplotlib
import matplotlib

# %matplotlib inline
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
#From:
#https://matplotlib.org/gallery/showcase/anatomy.html#sphx-glr-gallery-showcase-anatomy-py
#Note: If your output to running this cell is:
#
#    <Figure size 1200x1200 with 1 Axes>
#
# and you don't see a graph plotted, then run the cell a second time to get a nice graph!


import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter

np.random.seed(19680801)

X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

fig = plt.figure(figsize=(8, 8))  # You may have to adjust the figsize to fit your screen
ax = fig.add_subplot(1, 1, 1, aspect=1)


def minor_tick(x, pos):
    if not x % 1.0:
        return ""
    return "%.2f" % x

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

ax.plot(X, Y1, c=(0.25, 0.25, 1.00), lw=2, label="Blue signal", zorder=10)
ax.plot(X, Y2, c=(1.00, 0.25, 0.25), lw=2, label="Red signal")
ax.plot(X, Y3, linewidth=0,
        marker='o', markerfacecolor='w', markeredgecolor='k')

ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")

ax.legend()


def circle(x, y, radius=0.2):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='red', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)


def text(x, y, text):
    ax.text(x, y, text, backgroundcolor="yellow",
            ha='center', va='top', weight='bold', color='blue')


# Minor tick
circle(0.50, -0.10)
text(0.50, -0.32, "Minor tick label")

# Major tick
circle(-0.03, 4.00)
text(0.03, 3.80, "Major tick")

# Minor tick
circle(0.00, 3.50)
text(0.00, 3.30, "Minor tick")

# Major tick label
circle(-0.15, 3.00)
text(-0.15, 2.80, "Major tick label")

# X Label
circle(1.80, -0.27)
text(1.80, -0.45, "X axis label")

# Y Label
circle(-0.27, 1.80)
text(-0.27, 1.6, "Y axis label")

# Title
circle(1.0, 4.13)
text(1.10, 3.93, "Title")

# Blue plot
circle(1.75, 2.80)
text(1.75, 2.60, "Line\n(line plot)")

# Red plot
circle(1.20, 0.60)
text(1.20, 0.40, "Line\n(line plot)")

# Scatter plot
circle(3.20, 1.75)
text(3.20, 1.55, "Markers\n(scatter plot)")

# Grid
circle(3.00, 3.00)
text(3.00, 2.80, "Grid")

# Legend
circle(3.70, 3.80)
text(3.70, 3.60, "Legend")

# Axes
circle(0.5, 0.5)
text(0.5, 0.3, "Axes")

# Figure
circle(-0.3, 0.65)
text(-0.3, 0.45, "Figure")

color = 'blue'
ax.annotate('Spines', xy=(4.0, 0.35), xycoords='data',
            xytext=(3.3, 0.5), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.annotate('', xy=(3.15, 0.0), xycoords='data',
            xytext=(3.45, 0.45), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.text(4.0, -0.4, "Made with http://matplotlib.org",
        fontsize=10, ha="right", color='.5')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(19680801)

data = {'a': np.arange(100),
        'c': np.random.randint(0, 100, 100),
        'd': np.random.randn(100)}
data['b'] = data['a'] + 10 * np.random.randn(100)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(dpi=72*3)   # You may need to adjust dpi to fit your screen
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set(xlabel='entry a', ylabel='entry b')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot(dpi):
    fig, ax=plt.subplots(dpi=dpi)
    ax.plot([2,4,1,5], label="A Line")
    ax.legend()
    ax.set_title('Looks like a line!', fontsize=10)
# https://matplotlib.org/gallery/subplots_axes_and_figures/axis_equal_demo.html
#    ax.set_aspect('equal', 'box')
#    ax.set_aspect('equal')

# https://www.pythoncentral.io/pythons-range-function-explained/
for i in range(1,6):
    print(i,i*72/2)
    plot(i*72/2)
# Out:
# 1 36.0
# 2 72.0
# 3 108.0
# 4 144.0
# 5 180.0

# %% [markdown]
# ### Color Text
# #### ````<font color=blue|red|green|pink|yellow>Text</font>````
# #### Not all markdown code works within a font tag, so review your colored text carefully!
# <br>
# <font color=red>Red Text</font><br>
# <font color=blue>Blue Text</font><br>
# <font color=green>Green Text</font>

# %% [markdown]
# #### Some of this works on my Mac, but not on a PC....

# %%
from IPython.display import Markdown

def printmd(string, color=None, size=3):
    colorstr = "<span style='color:{}'> <font size='{}'> {}</span>".format(color, size, string)
    print(colorstr)
    display(Markdown(colorstr))
    
printmd("*text*")
printmd("<span style='color:red'>red text</span>")
printmd("Was GREEN in code!", color = "#00FF00", size='2')
for c in ('white', 'pink', 'violet', 'silver', 'cyan', "00FF00"):
    printmd("Writing in {}".format(c), color=c, size=6)
# Out:
# <span style='color:None'> <font size='3'> *text*</span>
# <span style='color:None'> <font size='3'> *text*</span>
# <span style='color:None'> <font size='3'> <span style='color:red'>red text</span></span>
# <span style='color:None'> <font size='3'> <span style='color:red'>red text</span></span>
# <span style='color:#00FF00'> <font size='2'> Was GREEN in code!</span>
# <span style='color:#00FF00'> <font size='2'> Was GREEN in code!</span>
# <span style='color:white'> <font size='6'> Writing in white</span>
# <span style='color:white'> <font size='6'> Writing in white</span>
# <span style='color:pink'> <font size='6'> Writing in pink</span>
# <span style='color:pink'> <font size='6'> Writing in pink</span>
# <span style='color:violet'> <font size='6'> Writing in violet</span>
# <span style='color:violet'> <font size='6'> Writing in violet</span>
# <span style='color:silver'> <font size='6'> Writing in silver</span>
# <span style='color:silver'> <font size='6'> Writing in silver</span>
# ...

# %% [markdown]
# ---
#
# ### Some more examples:
# > From: https://getbootstrap.com/docs/4.0/components/alerts/

# %% [markdown]
# <div class="alert alert-primary" role="alert">
#   This is a primary alert—check it out!
# </div>
# <div class="alert alert-secondary" role="alert">
#   This is a secondary alert—check it out!
# </div>
# <div class="alert alert-success" role="alert">
#   This is a success alert—check it out!
# </div>
# <div class="alert alert-danger" role="alert">
#   This is a danger alert—check it out!
# </div>
# <div class="alert alert-warning" role="alert">
#   This is a warning alert—check it out!
# </div>
# <div class="alert alert-info" role="alert">
#   This is a info alert—check it out!
# </div>
# <div class="alert alert-light" role="alert">
#   This is a light alert—check it out!
# </div>
# <div class="alert alert-dark" role="alert">
#   This is a dark alert—check it out!
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-primary" role="alert">
#   This is a primary alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>
# <div class="alert alert-secondary" role="alert">
#   This is a secondary alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>
# <div class="alert alert-success" role="alert">
#   This is a success alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>
# <div class="alert alert-danger" role="alert">
#   This is a danger alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>
# <div class="alert alert-warning" role="alert">
#   This is a warning alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>
# <div class="alert alert-info" role="alert">
#   This is a info alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>
# <div class="alert alert-light" role="alert">
#   This is a light alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>
# <div class="alert alert-dark" role="alert">
#   This is a dark alert with <a href="#" class="alert-link">an example link</a>. Give it a click if you like.
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Well done!</h4>
#   <p>Aww yeah, you successfully read this important alert message. </p>
#   <hr>
#
# </div>

# %% [markdown]
# ---
# ---

# %%
dt.datetime.today().strftime("%m/%d/%Y %H:%M:%S %p")
# Out:
# '11/03/2022 21:32:57 PM'

# %%
print("This Jupyter Notebook was run by:",My_Name)
# Out:
# This Jupyter Notebook was run by: Srijesh Reddy yarram

# %%
#Lets see the running time:

end = time.time()
print("Run time in seconds:",end - start)
print("or, time in minutes:", (end-start)/60)
# Out:
# Run time in seconds: 113.72913885116577
# or, time in minutes: 1.8954856475194295
